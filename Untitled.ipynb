# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import sigmoid_kernel, linear_kernel, cosine_similarity

# %%
data = pd.read_csv("Engineering_books_data.csv", encoding ="latin-1")

# %%
data
# Out:
#                                                   title  \
# 0     Soil Mechanics of Earthworks, Foundations and ...
# 1     Foundation Engineering: Design and Constructio...
# 2     Practical Problems in Soil Mechanics and Found...
# 3     Underwater Embankments on Soft Soil A Case His...
# 4     Eco- and Ground Bio-Engineering: The Use of Ve...
# ...                                                 ...
# 2370  Search Engines: Information Retrieval in Practice
# 2371                          Web Information Retrieval
# 2372                       Modern Information Retrieval
# 2373  Information Access through Search Engines and ...
# 2374  Issues in the Use of Neural Networks in Inform...
#
#                           author  \
# 0                            NaN
# 1                    B.B.K. Huat
# 2                  Sheng Y. Peng
# 3            William F. van Impe
# 4                  Alexia Stokes
# ...                          ...
# 2370              W. Bruce Croft
# 2371                Stefano Ceri
# 2372         Ricardo Baeza-Yates
# 2373  Maristella Agosti (Editor)
# 2374    Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/01...
# 1     https://covers.zlibcdn2.com/covers100/books/1b...
# 2     https://covers.zlibcdn2.com/covers100/books/7d...
# 3     https://covers.zlibcdn2.com/covers100/books/2b...
# 4     https://covers.zlibcdn2.com/covers100/books/d2...
# ...                                                 ...
# 2370  https://covers.zlibcdn2.com/covers100/books/01...
# 2371  https://covers.zlibcdn2.com/covers100/books/8e...
# 2372  https://covers.zlibcdn2.com/covers100/books/7f...
# 2373  https://covers.zlibcdn2.com/covers100/books/a7...
# 2374  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    This is the third volume...
# 1     \n                    Residual soils are found...
# 2                                                   NaN
# 3                                                   NaN
# 4     \n                    This volume brings toget...
# ...                                                 ...
# 2370                                                NaN
# 2371  \nWith the proliferation of huge amounts of (h...
# 2372  \n                    Discusses the changes in...
# 2373  \n                    The Information Manageme...
# 2374  \nThis book highlights the ability of neural n...
#
#                           download_link  pages  \
# 0     https://1lib.in/dl/2279969/9cd462  354.0
# 1     https://1lib.in/dl/1247565/f9e712  256.0
# 2     https://1lib.in/dl/2800423/3ccf77  346.0
# 3      https://1lib.in/dl/981008/e79e1d  154.0
# 4      https://1lib.in/dl/901430/e57c96  420.0
# ...                                 ...    ...
# 2370  https://1lib.in/dl/5148053/69b42b  542.0
# 2371  https://1lib.in/dl/2167059/097330  284.0
# 2372   https://1lib.in/dl/605897/eb0156  103.0
# 2373   https://1lib.in/dl/937104/93711b  214.0
# 2374  https://1lib.in/dl/2837743/71e6de  213.0
#
#                               publisher    year language           file
# 0                      Elsevier Science  1988.0  english   PDF, 9.35 MB
# 1                      Taylor & Francis  2006.0  english  PDF, 86.52 MB
# 2                  Elsevier Science Ltd  1985.0  english   PDF, 9.86 MB
# 3                                   NaN  2007.0  english   PDF, 3.35 MB
# 4                                   NaN  2007.0  english  PDF, 10.67 MB
# ...                                 ...     ...      ...            ...
# 2370                            Pearson  2009.0  english   PDF, 9.11 MB
# 2371  Springer-Verlag Berlin Heidelberg  2013.0  english   PDF, 7.44 MB
# 2372          ACM Press; Addison-Wesley  1999.0  english   PDF, 1.95 MB
# 2373                                NaN  2007.0  english   PDF, 3.67 MB
# 2374  Springer International Publishing  2017.0  english   PDF, 7.38 MB
#
# [2375 rows x 10 columns]

# %%
data.shape
# Out:
# (2375, 10)

# %%
# Droping the data having NaN values 
data = data.dropna()
data = data.reset_index(drop=True)

# %%
data.isnull().sum()
# Out:
# title            0
# author           0
# image            0
# desc             0
# download_link    0
# pages            0
# publisher        0
# year             0
# language         0
# file             0
# dtype: int64

# %%
# Droping the data whose description in NaN
data = data[data['desc'] !='Unknown']
data = data.reset_index(drop=True)
data.shape
# Out:
# (1439, 10)

# %%
# Droping the data whose download link in NaN
data = data[data['download_link'] != 'Unknown']
data = data.reset_index(drop=True)
data.shape
# Out:
# (1439, 10)

# %%
unknown_author = data[data['author'] == 'Unknown']
unknown_desc = data[data['desc'] == 'Unknown']
unknown_download_link = data[data['download_link'] == 'Unknown']
unknown_pages = data[data['pages'] == 'Unknown']
unknown_publisher = data[data['publisher'] == 'Unknown']
unknown_year = data[data['year'] == 'Unknown']
unknown_language = data[data['language'] == 'Unknown']
unknown_file = data[data['file'] == 'Unknown']
unknown_img = data[data['image'] == 'Unknown']

# %%
# Checking wheather there are any other important missing values 
print('unknown authors:', len(unknown_author))
print('unknown desc:',len(unknown_desc))
print('unknown download link:', len(unknown_download_link))
print('unknown pages:', len(unknown_pages))
print('unknown publisher:', len(unknown_publisher))
print('unknown year:', len(unknown_year))
print('unknown language:', len(unknown_language))
print('unknown file:', len(unknown_file))
print('unknown image:', len(unknown_img))
# Out:
# unknown authors: 0
# unknown desc: 0
# unknown download link: 0
# unknown pages: 0
# unknown publisher: 0
# unknown year: 0
# unknown language: 0
# unknown file: 0
# unknown image: 0

# %%
# changing to lower case inorder to droping duplicate title 
data['lower title'] = data['title'].str.lower()
data = data.drop_duplicates(subset=['lower title'])
data = data.reset_index(drop=True)
data.shape
# Out:
# (1214, 11)

# %%
# Getting the length of the title
data['title length'] = data.title.apply(len)

# %%
# distribution of length of the title
sns.distplot(data['title length'])
# Out:
# C:\Users\imert\AppData\Local\Temp\ipykernel_2468\3765079846.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['title length'])
# <Axes: xlabel='title length', ylabel='Density'>

# %%
# Removing some Outliers(title length which are more the 180 char)
data = data[data['title length'] < 180]
data = data.reset_index(drop=True)

# %%
# Distribution after removing outliers
sns.distplot(data['title length'])
# Out:
# C:\Users\imert\AppData\Local\Temp\ipykernel_2468\2566382381.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['title length'])
# <Axes: xlabel='title length', ylabel='Density'>

# %%
data.shape
# Out:
# (1203, 12)

# %%
# Description length
data['desc_length'] = data.desc.apply(len)

# %%
#Distribution and boxplot for description length
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
sns.histplot(data.desc_length, kde=True)

plt.subplot(1,2,2)
sns.boxplot(data.desc_length)
plt.show()

# %%
# removing records whose desc length is more the 5000
data = data[data['desc_length']<5000]
data = data.reset_index(drop=True)

# ploting Distribution and boxplot
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(data.desc_length, kde=True)
plt.subplot(1,2,2)
sns.boxplot(data.desc_length)
plt.show()

# %%
# cleaning description
data['clean desc'] = ''  # Yeni sütunu başlatma
for i in range(data.shape[0]):
    splited = data.loc[i, 'desc'].split()  # Her bir satırı almak için loc kullanımı
    clean_data = ' '.join(splited)  # Temizleme işlemi
    data.loc[i, 'clean desc'] = clean_data  # Yeni değeri loc ile atama

# %%
data.head()
# Out:
#                                                title                  author  \
# 0  Foundation Engineering: Design and Constructio...             B.B.K. Huat
# 1                       Principles of Thermodynamics  Jean-Philippe Ansermet
# 2  Thermodynamics: An Engineering Approach 8th Ed...        Yunus A. Ãengel
# 3  Thermal Physics: Thermodynamics and Statistica...       Robert F. Sekerka
# 4  Fundamentals of Physics: Mechanics, Relativity...              R. Shankar
#
#                                                image  \
# 0  https://covers.zlibcdn2.com/covers100/books/1b...
# 1  https://covers.zlibcdn2.com/covers100/books/29...
# 2  https://covers.zlibcdn2.com/covers100/books/6a...
# 3  https://covers.zlibcdn2.com/covers100/books/d0...
# 4  https://covers.zlibcdn2.com/covers100/books/15...
#
#                                                 desc  \
# 0  \n                    Residual soils are found...
# 1  \n                    In this introductory tex...
# 2  \nThermodynamics, An Engineering Approach, eig...
# 3  \nIn Thermal Physics: Thermodynamics and Stati...
# 4  \n                    Professor R. Shankar, a ...
#
#                        download_link   pages                   publisher  \
# 0  https://1lib.in/dl/1247565/f9e712   256.0            Taylor & Francis
# 1  https://1lib.in/dl/3685253/9f5b4e   529.0  Cambridge University Press
# 2  https://1lib.in/dl/2577672/7b237e  1115.0       McGraw-Hill Education
# 3  https://1lib.in/dl/2717455/9a083e   610.0                    Elsevier
# 4  https://1lib.in/dl/2577615/46ed97   464.0       Yale University Press
#
#      year language           file  \
# 0  2006.0  english  PDF, 86.52 MB
# 1  2019.0  english  PDF, 11.50 MB
# 2  2014.0  english  PDF, 64.77 MB
# 3  2015.0  english   PDF, 7.57 MB
# 4  2014.0  english   PDF, 3.80 MB
#
#                                          lower title  title length  \
# 0  foundation engineering: design and constructio...           144
# 1                       principles of thermodynamics            28
# 2  thermodynamics: an engineering approach 8th ed...            51
# 3  thermal physics: thermodynamics and statistica...            86
# 4  fundamentals of physics: mechanics, relativity...            66
#
#    desc_length                                         clean desc
# 0         1337  Residual soils are found in many parts of the ...
# 1         1018  In this introductory textbook, thermodynamics ...
# 2         1195  Thermodynamics, An Engineering Approach, eight...
# 3         1578  In Thermal Physics: Thermodynamics and Statist...
# 4         1105  Professor R. Shankar, a well-known physicist a...

# %%
# Creating new columns for recommendation using desc and title
data['recommend char'] = data['title'].str.lower() +' '+ data['clean desc'].str.lower()
data.head()
# Out:
#                                                title                  author  \
# 0  Foundation Engineering: Design and Constructio...             B.B.K. Huat
# 1                       Principles of Thermodynamics  Jean-Philippe Ansermet
# 2  Thermodynamics: An Engineering Approach 8th Ed...        Yunus A. Ãengel
# 3  Thermal Physics: Thermodynamics and Statistica...       Robert F. Sekerka
# 4  Fundamentals of Physics: Mechanics, Relativity...              R. Shankar
#
#                                                image  \
# 0  https://covers.zlibcdn2.com/covers100/books/1b...
# 1  https://covers.zlibcdn2.com/covers100/books/29...
# 2  https://covers.zlibcdn2.com/covers100/books/6a...
# 3  https://covers.zlibcdn2.com/covers100/books/d0...
# 4  https://covers.zlibcdn2.com/covers100/books/15...
#
#                                                 desc  \
# 0  \n                    Residual soils are found...
# 1  \n                    In this introductory tex...
# 2  \nThermodynamics, An Engineering Approach, eig...
# 3  \nIn Thermal Physics: Thermodynamics and Stati...
# 4  \n                    Professor R. Shankar, a ...
#
#                        download_link   pages                   publisher  \
# 0  https://1lib.in/dl/1247565/f9e712   256.0            Taylor & Francis
# 1  https://1lib.in/dl/3685253/9f5b4e   529.0  Cambridge University Press
# 2  https://1lib.in/dl/2577672/7b237e  1115.0       McGraw-Hill Education
# 3  https://1lib.in/dl/2717455/9a083e   610.0                    Elsevier
# 4  https://1lib.in/dl/2577615/46ed97   464.0       Yale University Press
#
#      year language           file  \
# 0  2006.0  english  PDF, 86.52 MB
# 1  2019.0  english  PDF, 11.50 MB
# 2  2014.0  english  PDF, 64.77 MB
# 3  2015.0  english   PDF, 7.57 MB
# 4  2014.0  english   PDF, 3.80 MB
#
#                                          lower title  title length  \
# 0  foundation engineering: design and constructio...           144
# 1                       principles of thermodynamics            28
# 2  thermodynamics: an engineering approach 8th ed...            51
# 3  thermal physics: thermodynamics and statistica...            86
# 4  fundamentals of physics: mechanics, relativity...            66
#
#    desc_length                                         clean desc  \
# 0         1337  Residual soils are found in many parts of the ...
# 1         1018  In this introductory textbook, thermodynamics ...
# 2         1195  Thermodynamics, An Engineering Approach, eight...
# 3         1578  In Thermal Physics: Thermodynamics and Statist...
# 4         1105  Professor R. Shankar, a well-known physicist a...
#
#                                       recommend char
# 0  foundation engineering: design and constructio...
# 1  principles of thermodynamics in this introduct...
# 2  thermodynamics: an engineering approach 8th ed...
# 3  thermal physics: thermodynamics and statistica...
# 4  fundamentals of physics: mechanics, relativity...

# %%
data['recommend char'][1]
# Out:
# "principles of thermodynamics in this introductory textbook, thermodynamics is presented as a natural extension of mechanics, so that the laws and concepts learned in mechanics serve to get acquainted with the theory. the foundations of thermodynamics are presented in the first part. the second part covers a wide range of applications, which are of central importance in the fields of physics, chemistry and engineering, including calorimetry, phase transitions, heat engines and chemical reactions. in the third part, devoted to continuous media, fourier and fick's laws, diffusion equations and many transport effects are derived using a unified approach. each chapter concludes with a selection of worked examples and several exercises, to reinforce key concepts under discussion. a full solutions manual is available at the end of the book. it contains more than 150 problems based on contemporary issues faced by scientists and engineers that are solved in detail for undergraduate and graduate students."

# %%
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\imert\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\imert\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#some stopwords are added...to get better results
my_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "youre", "youve", "youll", "youd", 
                'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 
                'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 
                'who', 'whom', 'this', 'that', "thatll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 
                'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 
                'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 
                'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 
                'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 
                'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 
                'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "dont", 'should', 
                "shouldve", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "arent", 'couldn', "couldnt", 
                'didn', "didnt", 'doesn', "doesnt", 'hadn', "hadnt", 'hasn', "hasnt", 'haven', "havent", 'isn', "isnt", 
                'ma', 'mightn', "mightnt", 'mustn', "mustnt", 'needn', "neednt", 'shan', "shant", 'shouldn', "shouldnt", 
                'wasn', "wasnt", 'weren', "werent", 'won', "wont", 'wouldn', "wouldnt",'book','many','also','may','part','chapter',
                'use','edition','course','first','second','third','fourth','fifth','sixth','seventh','every','textbook','using',
                'two','much','way','useful','provide','include','ha','including','one','page','used','today','take','based']

# %%
def cleaning(message):
    text = [char for char in message if char not in string.punctuation] #removing punctuation
    text = ''.join(text)
    text = [lemmatizer.lemmatize(word) for word in text.split()]  #using lemmatization
    text = ' '.join(text)
    text = [word for word in text.split() if word.lower() not in my_stopwords]   #removing stopwords
    text = ' '.join(text)
    return text

# %%
# cleaning by removing punctuation, stopwords and lemmatization
data['recommend char'] = data['recommend char'].apply(cleaning)
data['recommend char'][1]
# Out:
# 'principle thermodynamics introductory thermodynamics presented natural extension mechanic law concept learned mechanic serve get acquainted theory foundation thermodynamics presented cover wide range application central importance field physic chemistry engineering calorimetry phase transition heat engine chemical reaction devoted continuous medium fourier ficks law diffusion equation transport effect derived unified approach concludes selection worked example several exercise reinforce key concept discussion full solution manual available end contains 150 problem contemporary issue faced scientist engineer solved detail undergraduate graduate student'

# %%
#most frequently present words in recommend char
from wordcloud import WordCloud

wordcloud = WordCloud(background_color = 'purple', width = 2000, height = 2000).generate(' '.join(list(data['recommend char'])))

plt.style.use('fivethirtyeight')
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(wordcloud)
plt.title("Vocabulary from Descriptions", fontsize = 20)
plt.show()

# %%
data['recommend char2'] = data['lower title'].apply(cleaning)

# %%
#most frequent present words in recommend char2

from wordcloud import WordCloud

wordcloud = WordCloud(background_color = 'orange', width = 2000, height = 2000).generate(' '.join(list(data['recommend char2'])))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(wordcloud)
plt.title("Vocabulary from Title", fontsize = 20)
plt.show()

# %%
data.shape
# Out:
# (1200, 16)

# %%
data
# Out:
#                                                   title  \
# 0     Foundation Engineering: Design and Constructio...
# 1                          Principles of Thermodynamics
# 2     Thermodynamics: An Engineering Approach 8th Ed...
# 3     Thermal Physics: Thermodynamics and Statistica...
# 4     Fundamentals of Physics: Mechanics, Relativity...
# ...                                                 ...
# 1195  Semantic Knowledge Representation for Informat...
# 1196  Information Retrieval Systems: Theory and Impl...
# 1197            Opinion Mining In Information Retrieval
# 1198                          Web Information Retrieval
# 1199  Issues in the Use of Neural Networks in Inform...
#
#                         author  \
# 0                  B.B.K. Huat
# 1       Jean-Philippe Ansermet
# 2             Yunus A. Ãengel
# 3            Robert F. Sekerka
# 4                   R. Shankar
# ...                        ...
# 1195          Winfried GÃ¶dert
# 1196        Gerald J. Kowalski
# 1197             Surbhi Bhatia
# 1198              Stefano Ceri
# 1199  Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/1b...
# 1     https://covers.zlibcdn2.com/covers100/books/29...
# 2     https://covers.zlibcdn2.com/covers100/books/6a...
# 3     https://covers.zlibcdn2.com/covers100/books/d0...
# 4     https://covers.zlibcdn2.com/covers100/books/15...
# ...                                                 ...
# 1195  https://covers.zlibcdn2.com/covers100/books/58...
# 1196  https://covers.zlibcdn2.com/covers100/books/4f...
# 1197  https://covers.zlibcdn2.com/covers100/books/02...
# 1198  https://covers.zlibcdn2.com/covers100/books/8e...
# 1199  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    Residual soils are found...
# 1     \n                    In this introductory tex...
# 2     \nThermodynamics, An Engineering Approach, eig...
# 3     \nIn Thermal Physics: Thermodynamics and Stati...
# 4     \n                    Professor R. Shankar, a ...
# ...                                                 ...
# 1195  \nThis book covers the basics of semantic web ...
# 1196  \n                    The growth of the Intern...
# 1197  \n                    This book discusses in d...
# 1198  \nWith the proliferation of huge amounts of (h...
# 1199  \nThis book highlights the ability of neural n...
#
#                           download_link   pages  \
# 0     https://1lib.in/dl/1247565/f9e712   256.0
# 1     https://1lib.in/dl/3685253/9f5b4e   529.0
# 2     https://1lib.in/dl/2577672/7b237e  1115.0
# 3     https://1lib.in/dl/2717455/9a083e   610.0
# 4     https://1lib.in/dl/2577615/46ed97   464.0
# ...                                 ...     ...
# 1195  https://1lib.in/dl/3419364/81b614   294.0
# 1196  https://1lib.in/dl/1014014/bbb19e   290.0
# 1197  https://1lib.in/dl/5534593/695163   119.0
# 1198  https://1lib.in/dl/2167059/097330   284.0
# 1199  https://1lib.in/dl/2837743/71e6de   213.0
#
#                                publisher    year language           file  \
# 0                       Taylor & Francis  2006.0  english  PDF, 86.52 MB
# 1             Cambridge University Press  2019.0  english  PDF, 11.50 MB
# 2                  McGraw-Hill Education  2014.0  english  PDF, 64.77 MB
# 3                               Elsevier  2015.0  english   PDF, 7.57 MB
# 4                  Yale University Press  2014.0  english   PDF, 3.80 MB
# ...                                  ...     ...      ...            ...
# 1195                     De Gruyter Saur  2014.0  english   PDF, 7.75 MB
# 1196  The Information Retrieval Series 1  1997.0  english  PDF, 11.47 MB
# 1197                            Springer  2020.0  english   PDF, 3.41 MB
# 1198   Springer-Verlag Berlin Heidelberg  2013.0  english   PDF, 7.44 MB
# 1199   Springer International Publishing  2017.0  english   PDF, 7.38 MB
#
#                                             lower title  title length  \
# 0     foundation engineering: design and constructio...           144
# 1                          principles of thermodynamics            28
# 2     thermodynamics: an engineering approach 8th ed...            51
# 3     thermal physics: thermodynamics and statistica...            86
# 4     fundamentals of physics: mechanics, relativity...            66
# ...                                                 ...           ...
# 1195  semantic knowledge representation for informat...            59
# 1196  information retrieval systems: theory and impl...            56
# 1197            opinion mining in information retrieval            39
# 1198                          web information retrieval            25
# 1199  issues in the use of neural networks in inform...            61
#
#       desc_length                                         clean desc  \
# 0            1337  Residual soils are found in many parts of the ...
# 1            1018  In this introductory textbook, thermodynamics ...
# 2            1195  Thermodynamics, An Engineering Approach, eight...
# 3            1578  In Thermal Physics: Thermodynamics and Statist...
# 4            1105  Professor R. Shankar, a well-known physicist a...
# ...           ...                                                ...
# 1195          363  This book covers the basics of semantic web te...
# 1196         1654  The growth of the Internet and the availabilit...
# 1197         1048  This book discusses in detail the latest trend...
# 1198         2177  With the proliferation of huge amounts of (het...
# 1199          768  This book highlights the ability of neural net...
#
#                                          recommend char  \
# 0     foundation engineering design construction tro...
# 1     principle thermodynamics introductory thermody...
# 2     thermodynamics engineering approach 8th thermo...
# 3     thermal physic thermodynamics statistical mech...
# 4     fundamental physic mechanic relativity thermod...
# ...                                                 ...
# 1195  semantic knowledge representation information ...
# 1196  information retrieval system theory implementa...
# 1197  opinion mining information retrieval discusses...
# 1198  web information retrieval proliferation huge a...
# 1199  issue neural network information retrieval hig...
#
#                                         recommend char2
# 0     foundation engineering design construction tro...
# 1                              principle thermodynamics
# 2               thermodynamics engineering approach 8th
# 3     thermal physic thermodynamics statistical mech...
# 4     fundamental physic mechanic relativity thermod...
# ...                                                 ...
# 1195  semantic knowledge representation information ...
# 1196  information retrieval system theory implementa...
# 1197               opinion mining information retrieval
# 1198                          web information retrieval
# 1199         issue neural network information retrieval
#
# [1200 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1200 non-null   object
#  1   author           1200 non-null   object
#  2   image            1200 non-null   object
#  3   desc             1200 non-null   object
#  4   download_link    1200 non-null   object
#  5   pages            1200 non-null   float64
#  6   publisher        1200 non-null   object
#  7   year             1200 non-null   float64
#  8   language         1200 non-null   object
#  9   file             1200 non-null   object
#  10  lower title      1200 non-null   object
#  11  title length     1200 non-null   int64
#  12  desc_length      1200 non-null   int64
#  13  clean desc       1200 non-null   object
#  14  recommend char   1200 non-null   object
#  15  recommend char2  1200 non-null   object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 150.1+ KB
